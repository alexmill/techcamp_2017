# %% [markdown]
# # Session 5 Notes

# %% [markdown]
# ## Pandas `read_html`
#
# Make sure you have the following modules installed:
# - pandas
# - html5lib
# - lxml
# - BeautifulSoup4
#
# Install all of them with:
#
# `pip install pandas html5lib lxml BeautifulSoup4`.

# %%
import pandas as pd
import html5lib
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_television_markets")

# %%
type(tables)
# Out:
# list

# %%
dmas = tables[0]
dmas
# Out:
#         0                                1  \
# 0    Rank                           Market
# 1       1                         New York
# 2       2                      Los Angeles
# 3       3                          Chicago
# 4       4                     Philadelphia
# 5       5                Dallas-Fort Worth
# 6       6   San Francisco-Oakland-San Jose
# 7       7          Washington (Hagerstown)
# 8       8                          Houston
# 9       9              Boston (Manchester)
# 10     10                          Atlanta
# 11     11  Tampa-St. Petersburg (Sarasota)
# 12     12               Phoenix (Prescott)
# 13     13                          Detroit
# 14     14                   Seattle-Tacoma
# 15     15             Minneapolis-St. Paul
# 16     16            Miami-Fort Lauderdale
# 17     17                           Denver
# 18     18  Orlando-Daytona Beach-Melbourne
# 19     19         Cleveland-Akron (Canton)
# 20     20      Sacramento-Stockton-Modesto
# 21     21                        St. Louis
# 22     22                        Charlotte
# 23     23                       Pittsburgh
# 24     24    Raleigh-Durham (Fayetteville)
# 25     25                     Portland, OR
# 26     26                        Baltimore
# 27     27                     Indianapolis
# 28     28                        San Diego
# 29     29                        Nashville
# ..    ...                              ...
# 183   183                  Charlottesville
# 184   184                           Laredo
# 185   185                    Butte-Bozeman
# 186   186          Grand Junction-Montrose
# 187   187                    Lafayette, IN
# 188   188                         Bend, OR
# 189   189                             Lima
# 190   190                         Meridian
# 191   191                       Twin Falls
# 192   192                      Great Falls
# 193   193             Greenwood-Greenville
# 194   194                      Parkersburg
# 195   195                           Eureka
# 196   196                       San Angelo
# 197   197                  Casper-Riverton
# 198   198         Cheyenne-Scottsbluff, NE
# 199   199                          Mankato
# 200   200               Ottumwa-Kirksville
# 201   201                       St. Joseph
# 202   202                        Fairbanks
# 203   203                         Victoria
# 204   204                       Zanesville
# 205   205                           Helena
# 206   206                     Presque Isle
# 207   207                           Juneau
# 208   208                           Alpena
# 209   209                     North Platte
# 210   210                         Glendive
# 211   NaN                             Guam
# 212   NaN                      Puerto Rico
#
#                                                      2  \
# 0                                                State
# 1                                             New York
# 2                                           California
# 3                                             Illinois
# 4                                         Pennsylvania
# 5                                                Texas
# 6                                           California
# 7                                 District of Columbia
# 8                                                Texas
# 9                                        Massachusetts
# 10                                             Georgia
# 11                                             Florida
# 12                                             Arizona
# 13                                            Michigan
# 14                                          Washington
# 15                                           Minnesota
# 16                                             Florida
# 17                                            Colorado
# 18                                             Florida
# 19                                                Ohio
# 20                                          California
# 21                                            Missouri
# 22                                      North Carolina
# 23                                        Pennsylvania
# 24                                      North Carolina
# 25                                              Oregon
# 26                                            Maryland
# 27                                             Indiana
# 28                                          California
# 29                                           Tennessee
# ..                                                 ...
# 183                                           Virginia
# 184                                              Texas
# 185                                            Montana
# 186                                           Colorado
# 187                                            Indiana
# 188                                             Oregon
# 189                                               Ohio
# 190                                        Mississippi
# 191                                              Idaho
# 192                                            Montana
# 193                                        Mississippi
# 194                                      West Virginia
# 195                                         California
# 196                                              Texas
# 197                                            Wyoming
# 198                                            Wyoming
# 199                                          Minnesota
# 200                                               Iowa
# 201                                           Missouri
# 202                                             Alaska
# 203                                              Texas
# 204                                               Ohio
# 205                                            Montana
# 206                                              Maine
# 207                                             Alaska
# 208                                           Michigan
# 209                                           Nebraska
# 210                                            Montana
# 211                                  Hagåtña (village)
# 212  Adjuntas, Aguada, Aguadilla, Aguas Buenas, Aib...
#
#                                                      3  \
# 0             Counties (or county-equivalents) covered
# 1    New York: Bronx, Dutchess, Kings, Nassau, New ...
# 2    Inyo, Kern (Sierra Nevada), Los Angeles, Orang...
# 3    Illinois: Cook, DeKalb, DuPage, Grundy, Kane, ...
# 4    Pennsylvania: Berks, Bucks, Chester, Delaware,...
# 5    Anderson, Bosque, Collin, Comanche, Cooke, Dal...
# 6    Alameda, Contra Costa, Lake, Marin, Mendocino,...
# 7    District of Columbia: Washington Virginia: Ale...
# 8    Austin, Brazoria, Calhoun, Chambers, Colorado,...
# 9    Massachusetts: Barnstable, Dukes, Essex, Middl...
# 10   Georgia: Banks, Barrow, Bartow, Butts, Carroll...
# 11   Citrus, Hardee, Hernando, Highlands, Hillsboro...
# 12   Apache (southern third), Coconino, Gila, Graha...
# 13   Lapeer, Livingston, Macomb, Monroe, Oakland, S...
# 14   Chelan, Clallam, Douglas, Grays Harbor, Island...
# 15   Minnesota: Anoka, Beltrami, Benton, Big Stone,...
# 16                         Broward, Miami-Dade, Monroe
# 17   Colorado: Adams, Alamosa, Arapahoe, Archuleta,...
# 18   Brevard, Flagler, Lake, Marion, Orange, Osceol...
# 19   Ashland, Ashtabula, Carroll, Cuyahoga, Erie, G...
# 20   Amador, Calaveras, Colusa, El Dorado (west), N...
# 21   Missouri: Crawford, Franklin, Gasconade, Iron,...
# 22   North Carolina: Alexander, Anson, Ashe, Avery,...
# 23   Pennsylvania: Allegheny, Armstrong, Beaver, Bu...
# 24   North Carolina: Chatham, Cumberland, Durham, E...
# 25   Oregon: Baker, Clackamas, Clatsop, Columbia, C...
# 26   Anne Arundel, Baltimore (city), Baltimore Coun...
# 27   Bartholomew, Benton, Blackford, Boone, Brown, ...
# 28                                           San Diego
# 29   Tennessee: Bedford, Benton, Cannon, Cheatham, ...
# ..                                                 ...
# 183  Albemarle, Charlottesville (city),[2] Greene, ...
# 184                                       Webb, Zapata
# 185  Beaverhead, Broadwater, Deer Lodge, Gallatin, ...
# 186                            Dolores, Mesa, Montrose
# 187                                 Tippecanoe, Warren
# 188                                          Deschutes
# 189                                              Allen
# 190  Mississippi: Clarke, Kemper, Lauderdale, Nesho...
# 191  Blaine, Cassia, Gooding, Jerome, Lincoln, Mini...
# 192  Blaine, Cascade, Chouteau, Fergus, Glacier, Hi...
# 193  Mississippi: Bolivar, Carroll, Grenada, Leflor...
# 194    West Virginia: Pleasants, Wood Ohio: Washington
# 195                                Del Norte, Humboldt
# 196  Coke, Concho, Crockett, Irion, Kimble, McCullo...
# 197  Converse, Fremont, Hot Springs, Johnson, Natro...
# 198    Wyoming: Goshen, Laramie Nebraska: Scotts Bluff
# 199  Minnesota: Blue Earth, Brown, Martin, Watonwan...
# 200  Iowa: Davis, Jefferson, Van Buren, Wapello Mis...
# 201  Missouri: Andrew, Buchanan, DeKalb, Holt, Noda...
# 202  Denali, Fairbanks North Star, Southeast Fairba...
# 203                                           Victoria
# 204                                          Muskingum
# 205                                    Lewis and Clark
# 206                                          Aroostook
# 207  Haines, Hoonah-Angoon, Juneau, Ketchikan Gatew...
# 208                                     Alcona, Alpena
# 209  Arthur, Blaine, Hooker, Lincoln, Logan, McPher...
# 210                            Dawson, Fallon, Prairie
# 211                                                NaN
# 212                                                NaN
#
#                                                      4  \
# 0                              TV households (2016–17)
# 1                                   7,348,620 (6.407%)
# 2                                   5,476,830 (4.775%)
# 3                                   3,463,060 (3.019%)
# 4                                   2,942,800 (2.566%)
# 5                                   2,713,380 (2.366%)
# 6                                   2,488,090 (2.169%)
# 7                                   2,476,680 (2.159%)
# 8                                   2,450,800 (2.137%)
# 9                                   2,424,240 (2.114%)
# 10                                  2,412,730 (2.104%)
# 11                                  1,908,590 (1.664%)
# 12                                  1,890,100 (1.648%)
# 13                                  1,853,030 (1.616%)
# 14                                  1,808,530 (1.577%)
# 15                                  1,742,530 (1.519%)
# 16                                  1,696,330 (1.479%)
# 17                                  1,630,380 (1.422%)
# 18                                  1,519,570 (1.325%)
# 19                                  1,498,960 (1.307%)
# 20                                  1,379,770 (1.203%)
# 21                                  1,215,570 (1.060%)
# 22                                  1,189,950 (1.038%)
# 23                                  1,160,220 (1.012%)
# 24                                  1,153,680 (1.006%)
# 25                                  1,143,670 (0.997%)
# 26                                  1,119,480 (0.976%)
# 27                                  1,086,310 (0.947%)
# 28                                  1,065,700 (0.929%)
# 29                                  1,011,570 (0.882%)
# ..                                                 ...
# 183                                    74,990 (0.065%)
# 184                                    74,330 (0.065%)
# 185                                    70,320 (0.061%)
# 186                                    69,820 (0.061%)
# 187                                    69,180 (0.060%)
# 188                                    67,430 (0.059%)
# 189                                    66,570 (0.058%)
# 190                                    65,300 (0.057%)
# 191                                    64,190 (0.056%)
# 192                                    63,720 (0.056%)
# 193                                    62,690 (0.055%)
# 194                                    60,620 (0.053%)
# 195                                    58,640 (0.051%)
# 196                                    56,680 (0.049%)
# 197                                    56,260 (0.049%)
# 198                                    56,120 (0.049%)
# 199                                    51,820 (0.045%)
# 200                                    44,690 (0.039%)
# 201                                    44,460 (0.039%)
# 202                                    36,070 (0.031%)
# 203                                    32,930 (0.029%)
# 204                                    32,450 (0.028%)
# 205                                    28,110 (0.025%)
# 206                                    26,880 (0.023%)
# 207                                    25,680 (0.022%)
# 208                                    16,010 (0.014%)
# 209                                    14,370 (0.013%)
# 210                                     4,370 (0.004%)
# 211  KEQI-LP (Fox/ABS-CBN/ANC) (KTGM), KTGM (ABC) (...
# 212  W10DB-D (CBS) (W17DL-D (MeTV)/W25EF-D (Ion)/W4...
#
#                                                      5
# 0    Major network affiliates (ABC, CBS, Fox, NBC) ...
# 1    WABC-TV (ABC), WCBS-TV (CBS) (WLNY-TV (Indepen...
# 2    KABC-TV (ABC), KCBS-TV (CBS) (KCAL-TV (Indepen...
# 3    WBBM-TV (CBS), WFLD (Fox) (WPWR-TV (CW/MyNetwo...
# 4    KYW-TV (CBS) (WPSG (CW)), WCAU (NBC) (WWSI (Te...
# 5    KDFW (Fox) (KDFI (MyNetworkTV)), KTVT (CBS) (K...
# 6    KGO-TV (ABC), KNTV (NBC) (KSTS (Telemundo)), K...
# 7    WJLA-TV (ABC), WRC-TV (NBC), WTTG (Fox) (WDCA ...
# 8    KHOU (CBS), KPRC-TV (NBC), KRIV (Fox) (KTXH (M...
# 9    WBTS-LD/WNEU-DT2/WMFP-DT5 (NBC) (WNEU (Telemun...
# 10   WAGA-TV (Fox), WGCL-TV (CBS) (WPCH-TV (Indepen...
# 11   WFLA-TV (NBC) (WTTA (MyNetworkTV)), WFTS-TV (A...
# 12   KNXV-TV (ABC), KPHO-TV (CBS) (KTVK (Independen...
# 13   WDIV-TV (NBC), WJBK (Fox), WWJ-TV (CBS) (WKBD-...
# 14   KCPQ (Fox) (KZJO (MyNetworkTV)), KING-TV (NBC)...
# 15   KARE (NBC), KMSP-TV (Fox) (WFTC (MyNetworkTV))...
# 16   WFOR-TV (CBS) (WBFS-TV (MyNetworkTV)), WPLG (A...
# 17   KCNC-TV (CBS), KDVR/KFCT (Fox) (KWGN-TV (CW)),...
# 18   WESH (NBC) (WKCF (CW)), WFTV (ABC) (WRDQ (Inde...
# 19   WEWS-TV (ABC), WJW (Fox), WKYC (NBC), and WOIO...
# 20   KCRA-TV (NBC) (KQCA (MyNetworkTV), KOVR (CBS) ...
# 21   KDNL-TV (ABC), KMOV (CBS), KSDK (NBC), and KTV...
# 22   WBTV (CBS), WCNC-TV (NBC), WJZY (Fox) (WMYT-TV...
# 23   KDKA-TV (CBS) (WPCW (CW)), WPGH-TV (Fox) (WPNT...
# 24   WNCN (CBS), WRAL-TV (NBC) (WRAZ), WRAZ (Fox) (...
# 25   KATU (ABC) (KUNP (Univision)), KGW (NBC), KOIN...
# 26   WBAL-TV (NBC), WBFF (Fox) (WUTB (MyNetworkTV)/...
# 27   WRTV (ABC), WTHR (NBC) (WALV-CD (Cozi TV)), WT...
# 28   KFMB-TV (CBS), KGTV (ABC) (KZSD-LP (MeTV)), KN...
# 29   WKRN-TV (ABC), WSMV-TV (NBC), WTVF (CBS), and ...
# ..                                                 ...
# 183  WAHU-CD (Fox) (WCAV/WVAW-LD), WCAV (CBS) (WAHU...
# 184  KGNS-TV (NBC) (KYLX-LD), KGNS-DT2 (ABC) (KYLX-...
# 185  KTVM (NBC), KWYB (ABC), KWYB-DT2 (Fox/MyNetwor...
# 186  KFQX (Fox) (KREX-TV/KREY-TV/KGJT-CD (MyNetwork...
# 187  WLFI-TV (CBS), WPBI-LD (Fox), WPBI-LD2 (NBC), ...
# 188  KBNZ-LD (CBS) (KOHD), KFXO-LD (Fox) (KTVZ/KQRE...
# 189  WLIO (NBC) (WOHL-CD (and CD2)/WLQP-LP/WLMO-LP)...
# 190  WGBC (Fox) (WMDN), WGBC-DT2 (NBC) (WMDN), WMDN...
# 191  KMVT (CBS) (KSVT-LD), KSAW-LD (ABC), KSVT-LD (...
# 192  KBGF-LD (NBC) (KRTV), KFBB-TV (ABC), KFBB-DT2 ...
# 193  WABG-TV (ABC) (WFXW-LD/WNBD-LD/"WXVT"), WFXW-L...
# 194  WIYE-LD (CBS) (WOVA-LD/WTAP-TV), WOVA-LD (Fox)...
# 195  KAEF (ABC) (KBVU), KBVU (Fox) (KAEF), KIEM-TV ...
# 196  KIDY (Fox), KLST (CBS) (KSAN-TV), KSAN-TV (NBC...
# 197  KCWY-DT (NBC), KFNB/KFNE/KFNR (Fox) (KWYF-LD (...
# 198  KCHY-LP/KWYM-LP (NBC) (KGWN-TV/KSTF), KDUH-TV ...
# 199  KEYC-TV (CBS) and KEYC-DT2 (Fox); no local ABC...
# 200  KTVO (ABC), KTVO-DT2 (CBS), and KYOU-TV (Fox);...
# 201  KCJO-LD (CBS) (KNPG-LD/KNPN-LD), KNPG-LD (NBC)...
# 202  KATN (ABC), KFXF-LD (Fox) (KTVF/KXDF-CD), KTVF...
# 203  KAVU-TV (ABC) (KMOL-LD/KUNU-LD (Univision)/KVC...
# 204  WHIZ-TV (NBC); no local ABC, CBS, or Fox affil...
# 205  KHBB-LD (ABC), KHBB-LD2 (Fox/MyNetworkTV/Jewel...
# 206  WAGM-TV (Fox) and WAGM-DT2 (CBS); no local ABC...
# 207  KATH-LD (NBC) (KXLJ-LD), KJUD (ABC), KJUD-DT2 ...
# 208  WBKB-TV (CBS), WBKB-DT2 (Fox/MyNetworkTV), and...
# 209  KHGI-CD (ABC), KIIT-CD (Fox) (KNOP-TV/KNPL-LD)...
# 210  KXGN-TV (CBS) and KXGN-DT2 (NBC); no local ABC...
# 211                                                NaN
# 212                                                NaN
#
# [213 rows x 6 columns]

# %%
dmas.columns = dmas.iloc[0,:]
dmas = dmas.drop(0).reset_index(drop=True)

# %%
dmas
# Out:
# 0   Rank                           Market  \
# 0      1                         New York
# 1      2                      Los Angeles
# 2      3                          Chicago
# 3      4                     Philadelphia
# 4      5                Dallas-Fort Worth
# 5      6   San Francisco-Oakland-San Jose
# 6      7          Washington (Hagerstown)
# 7      8                          Houston
# 8      9              Boston (Manchester)
# 9     10                          Atlanta
# 10    11  Tampa-St. Petersburg (Sarasota)
# 11    12               Phoenix (Prescott)
# 12    13                          Detroit
# 13    14                   Seattle-Tacoma
# 14    15             Minneapolis-St. Paul
# 15    16            Miami-Fort Lauderdale
# 16    17                           Denver
# 17    18  Orlando-Daytona Beach-Melbourne
# 18    19         Cleveland-Akron (Canton)
# 19    20      Sacramento-Stockton-Modesto
# 20    21                        St. Louis
# 21    22                        Charlotte
# 22    23                       Pittsburgh
# 23    24    Raleigh-Durham (Fayetteville)
# 24    25                     Portland, OR
# 25    26                        Baltimore
# 26    27                     Indianapolis
# 27    28                        San Diego
# 28    29                        Nashville
# 29    30             Hartford & New Haven
# ..   ...                              ...
# 182  183                  Charlottesville
# 183  184                           Laredo
# 184  185                    Butte-Bozeman
# 185  186          Grand Junction-Montrose
# 186  187                    Lafayette, IN
# 187  188                         Bend, OR
# 188  189                             Lima
# 189  190                         Meridian
# 190  191                       Twin Falls
# 191  192                      Great Falls
# 192  193             Greenwood-Greenville
# 193  194                      Parkersburg
# 194  195                           Eureka
# 195  196                       San Angelo
# 196  197                  Casper-Riverton
# 197  198         Cheyenne-Scottsbluff, NE
# 198  199                          Mankato
# 199  200               Ottumwa-Kirksville
# 200  201                       St. Joseph
# 201  202                        Fairbanks
# 202  203                         Victoria
# 203  204                       Zanesville
# 204  205                           Helena
# 205  206                     Presque Isle
# 206  207                           Juneau
# 207  208                           Alpena
# 208  209                     North Platte
# 209  210                         Glendive
# 210  NaN                             Guam
# 211  NaN                      Puerto Rico
#
# 0                                                State  \
# 0                                             New York
# 1                                           California
# 2                                             Illinois
# 3                                         Pennsylvania
# 4                                                Texas
# 5                                           California
# 6                                 District of Columbia
# 7                                                Texas
# 8                                        Massachusetts
# 9                                              Georgia
# 10                                             Florida
# 11                                             Arizona
# 12                                            Michigan
# 13                                          Washington
# 14                                           Minnesota
# 15                                             Florida
# 16                                            Colorado
# 17                                             Florida
# 18                                                Ohio
# 19                                          California
# 20                                            Missouri
# 21                                      North Carolina
# 22                                        Pennsylvania
# 23                                      North Carolina
# 24                                              Oregon
# 25                                            Maryland
# 26                                             Indiana
# 27                                          California
# 28                                           Tennessee
# 29                                         Connecticut
# ..                                                 ...
# 182                                           Virginia
# 183                                              Texas
# 184                                            Montana
# 185                                           Colorado
# 186                                            Indiana
# 187                                             Oregon
# 188                                               Ohio
# 189                                        Mississippi
# 190                                              Idaho
# 191                                            Montana
# 192                                        Mississippi
# 193                                      West Virginia
# 194                                         California
# 195                                              Texas
# 196                                            Wyoming
# 197                                            Wyoming
# 198                                          Minnesota
# 199                                               Iowa
# 200                                           Missouri
# 201                                             Alaska
# 202                                              Texas
# 203                                               Ohio
# 204                                            Montana
# 205                                              Maine
# 206                                             Alaska
# 207                                           Michigan
# 208                                           Nebraska
# 209                                            Montana
# 210                                  Hagåtña (village)
# 211  Adjuntas, Aguada, Aguadilla, Aguas Buenas, Aib...
#
# 0             Counties (or county-equivalents) covered  \
# 0    New York: Bronx, Dutchess, Kings, Nassau, New ...
# 1    Inyo, Kern (Sierra Nevada), Los Angeles, Orang...
# 2    Illinois: Cook, DeKalb, DuPage, Grundy, Kane, ...
# 3    Pennsylvania: Berks, Bucks, Chester, Delaware,...
# 4    Anderson, Bosque, Collin, Comanche, Cooke, Dal...
# 5    Alameda, Contra Costa, Lake, Marin, Mendocino,...
# 6    District of Columbia: Washington Virginia: Ale...
# 7    Austin, Brazoria, Calhoun, Chambers, Colorado,...
# 8    Massachusetts: Barnstable, Dukes, Essex, Middl...
# 9    Georgia: Banks, Barrow, Bartow, Butts, Carroll...
# 10   Citrus, Hardee, Hernando, Highlands, Hillsboro...
# 11   Apache (southern third), Coconino, Gila, Graha...
# 12   Lapeer, Livingston, Macomb, Monroe, Oakland, S...
# 13   Chelan, Clallam, Douglas, Grays Harbor, Island...
# 14   Minnesota: Anoka, Beltrami, Benton, Big Stone,...
# 15                         Broward, Miami-Dade, Monroe
# 16   Colorado: Adams, Alamosa, Arapahoe, Archuleta,...
# 17   Brevard, Flagler, Lake, Marion, Orange, Osceol...
# 18   Ashland, Ashtabula, Carroll, Cuyahoga, Erie, G...
# 19   Amador, Calaveras, Colusa, El Dorado (west), N...
# 20   Missouri: Crawford, Franklin, Gasconade, Iron,...
# 21   North Carolina: Alexander, Anson, Ashe, Avery,...
# 22   Pennsylvania: Allegheny, Armstrong, Beaver, Bu...
# 23   North Carolina: Chatham, Cumberland, Durham, E...
# 24   Oregon: Baker, Clackamas, Clatsop, Columbia, C...
# 25   Anne Arundel, Baltimore (city), Baltimore Coun...
# 26   Bartholomew, Benton, Blackford, Boone, Brown, ...
# 27                                           San Diego
# 28   Tennessee: Bedford, Benton, Cannon, Cheatham, ...
# 29   Hartford, Litchfield, Middlesex, New Haven, Ne...
# ..                                                 ...
# 182  Albemarle, Charlottesville (city),[2] Greene, ...
# 183                                       Webb, Zapata
# 184  Beaverhead, Broadwater, Deer Lodge, Gallatin, ...
# 185                            Dolores, Mesa, Montrose
# 186                                 Tippecanoe, Warren
# 187                                          Deschutes
# 188                                              Allen
# 189  Mississippi: Clarke, Kemper, Lauderdale, Nesho...
# 190  Blaine, Cassia, Gooding, Jerome, Lincoln, Mini...
# 191  Blaine, Cascade, Chouteau, Fergus, Glacier, Hi...
# 192  Mississippi: Bolivar, Carroll, Grenada, Leflor...
# 193    West Virginia: Pleasants, Wood Ohio: Washington
# 194                                Del Norte, Humboldt
# 195  Coke, Concho, Crockett, Irion, Kimble, McCullo...
# 196  Converse, Fremont, Hot Springs, Johnson, Natro...
# 197    Wyoming: Goshen, Laramie Nebraska: Scotts Bluff
# 198  Minnesota: Blue Earth, Brown, Martin, Watonwan...
# 199  Iowa: Davis, Jefferson, Van Buren, Wapello Mis...
# 200  Missouri: Andrew, Buchanan, DeKalb, Holt, Noda...
# 201  Denali, Fairbanks North Star, Southeast Fairba...
# 202                                           Victoria
# 203                                          Muskingum
# 204                                    Lewis and Clark
# 205                                          Aroostook
# 206  Haines, Hoonah-Angoon, Juneau, Ketchikan Gatew...
# 207                                     Alcona, Alpena
# 208  Arthur, Blaine, Hooker, Lincoln, Logan, McPher...
# 209                            Dawson, Fallon, Prairie
# 210                                                NaN
# 211                                                NaN
#
# 0                              TV households (2016–17)  \
# 0                                   7,348,620 (6.407%)
# 1                                   5,476,830 (4.775%)
# 2                                   3,463,060 (3.019%)
# 3                                   2,942,800 (2.566%)
# 4                                   2,713,380 (2.366%)
# 5                                   2,488,090 (2.169%)
# 6                                   2,476,680 (2.159%)
# 7                                   2,450,800 (2.137%)
# 8                                   2,424,240 (2.114%)
# 9                                   2,412,730 (2.104%)
# 10                                  1,908,590 (1.664%)
# 11                                  1,890,100 (1.648%)
# 12                                  1,853,030 (1.616%)
# 13                                  1,808,530 (1.577%)
# 14                                  1,742,530 (1.519%)
# 15                                  1,696,330 (1.479%)
# 16                                  1,630,380 (1.422%)
# 17                                  1,519,570 (1.325%)
# 18                                  1,498,960 (1.307%)
# 19                                  1,379,770 (1.203%)
# 20                                  1,215,570 (1.060%)
# 21                                  1,189,950 (1.038%)
# 22                                  1,160,220 (1.012%)
# 23                                  1,153,680 (1.006%)
# 24                                  1,143,670 (0.997%)
# 25                                  1,119,480 (0.976%)
# 26                                  1,086,310 (0.947%)
# 27                                  1,065,700 (0.929%)
# 28                                  1,011,570 (0.882%)
# 29                                    963,950 (0.840%)
# ..                                                 ...
# 182                                    74,990 (0.065%)
# 183                                    74,330 (0.065%)
# 184                                    70,320 (0.061%)
# 185                                    69,820 (0.061%)
# 186                                    69,180 (0.060%)
# 187                                    67,430 (0.059%)
# 188                                    66,570 (0.058%)
# 189                                    65,300 (0.057%)
# 190                                    64,190 (0.056%)
# 191                                    63,720 (0.056%)
# 192                                    62,690 (0.055%)
# 193                                    60,620 (0.053%)
# 194                                    58,640 (0.051%)
# 195                                    56,680 (0.049%)
# 196                                    56,260 (0.049%)
# 197                                    56,120 (0.049%)
# 198                                    51,820 (0.045%)
# 199                                    44,690 (0.039%)
# 200                                    44,460 (0.039%)
# 201                                    36,070 (0.031%)
# 202                                    32,930 (0.029%)
# 203                                    32,450 (0.028%)
# 204                                    28,110 (0.025%)
# 205                                    26,880 (0.023%)
# 206                                    25,680 (0.022%)
# 207                                    16,010 (0.014%)
# 208                                    14,370 (0.013%)
# 209                                     4,370 (0.004%)
# 210  KEQI-LP (Fox/ABS-CBN/ANC) (KTGM), KTGM (ABC) (...
# 211  W10DB-D (CBS) (W17DL-D (MeTV)/W25EF-D (Ion)/W4...
#
# 0   Major network affiliates (ABC, CBS, Fox, NBC) Sister stations
# 0    WABC-TV (ABC), WCBS-TV (CBS) (WLNY-TV (Indepen...
# 1    KABC-TV (ABC), KCBS-TV (CBS) (KCAL-TV (Indepen...
# 2    WBBM-TV (CBS), WFLD (Fox) (WPWR-TV (CW/MyNetwo...
# 3    KYW-TV (CBS) (WPSG (CW)), WCAU (NBC) (WWSI (Te...
# 4    KDFW (Fox) (KDFI (MyNetworkTV)), KTVT (CBS) (K...
# 5    KGO-TV (ABC), KNTV (NBC) (KSTS (Telemundo)), K...
# 6    WJLA-TV (ABC), WRC-TV (NBC), WTTG (Fox) (WDCA ...
# 7    KHOU (CBS), KPRC-TV (NBC), KRIV (Fox) (KTXH (M...
# 8    WBTS-LD/WNEU-DT2/WMFP-DT5 (NBC) (WNEU (Telemun...
# 9    WAGA-TV (Fox), WGCL-TV (CBS) (WPCH-TV (Indepen...
# 10   WFLA-TV (NBC) (WTTA (MyNetworkTV)), WFTS-TV (A...
# 11   KNXV-TV (ABC), KPHO-TV (CBS) (KTVK (Independen...
# 12   WDIV-TV (NBC), WJBK (Fox), WWJ-TV (CBS) (WKBD-...
# 13   KCPQ (Fox) (KZJO (MyNetworkTV)), KING-TV (NBC)...
# 14   KARE (NBC), KMSP-TV (Fox) (WFTC (MyNetworkTV))...
# 15   WFOR-TV (CBS) (WBFS-TV (MyNetworkTV)), WPLG (A...
# 16   KCNC-TV (CBS), KDVR/KFCT (Fox) (KWGN-TV (CW)),...
# 17   WESH (NBC) (WKCF (CW)), WFTV (ABC) (WRDQ (Inde...
# 18   WEWS-TV (ABC), WJW (Fox), WKYC (NBC), and WOIO...
# 19   KCRA-TV (NBC) (KQCA (MyNetworkTV), KOVR (CBS) ...
# 20   KDNL-TV (ABC), KMOV (CBS), KSDK (NBC), and KTV...
# 21   WBTV (CBS), WCNC-TV (NBC), WJZY (Fox) (WMYT-TV...
# 22   KDKA-TV (CBS) (WPCW (CW)), WPGH-TV (Fox) (WPNT...
# 23   WNCN (CBS), WRAL-TV (NBC) (WRAZ), WRAZ (Fox) (...
# 24   KATU (ABC) (KUNP (Univision)), KGW (NBC), KOIN...
# 25   WBAL-TV (NBC), WBFF (Fox) (WUTB (MyNetworkTV)/...
# 26   WRTV (ABC), WTHR (NBC) (WALV-CD (Cozi TV)), WT...
# 27   KFMB-TV (CBS), KGTV (ABC) (KZSD-LP (MeTV)), KN...
# 28   WKRN-TV (ABC), WSMV-TV (NBC), WTVF (CBS), and ...
# 29   WFSB (CBS), WTIC-TV (Fox) (WCCT-TV (CW)), WTNH...
# ..                                                 ...
# 182  WAHU-CD (Fox) (WCAV/WVAW-LD), WCAV (CBS) (WAHU...
# 183  KGNS-TV (NBC) (KYLX-LD), KGNS-DT2 (ABC) (KYLX-...
# 184  KTVM (NBC), KWYB (ABC), KWYB-DT2 (Fox/MyNetwor...
# 185  KFQX (Fox) (KREX-TV/KREY-TV/KGJT-CD (MyNetwork...
# 186  WLFI-TV (CBS), WPBI-LD (Fox), WPBI-LD2 (NBC), ...
# 187  KBNZ-LD (CBS) (KOHD), KFXO-LD (Fox) (KTVZ/KQRE...
# 188  WLIO (NBC) (WOHL-CD (and CD2)/WLQP-LP/WLMO-LP)...
# 189  WGBC (Fox) (WMDN), WGBC-DT2 (NBC) (WMDN), WMDN...
# 190  KMVT (CBS) (KSVT-LD), KSAW-LD (ABC), KSVT-LD (...
# 191  KBGF-LD (NBC) (KRTV), KFBB-TV (ABC), KFBB-DT2 ...
# 192  WABG-TV (ABC) (WFXW-LD/WNBD-LD/"WXVT"), WFXW-L...
# 193  WIYE-LD (CBS) (WOVA-LD/WTAP-TV), WOVA-LD (Fox)...
# 194  KAEF (ABC) (KBVU), KBVU (Fox) (KAEF), KIEM-TV ...
# 195  KIDY (Fox), KLST (CBS) (KSAN-TV), KSAN-TV (NBC...
# 196  KCWY-DT (NBC), KFNB/KFNE/KFNR (Fox) (KWYF-LD (...
# 197  KCHY-LP/KWYM-LP (NBC) (KGWN-TV/KSTF), KDUH-TV ...
# 198  KEYC-TV (CBS) and KEYC-DT2 (Fox); no local ABC...
# 199  KTVO (ABC), KTVO-DT2 (CBS), and KYOU-TV (Fox);...
# 200  KCJO-LD (CBS) (KNPG-LD/KNPN-LD), KNPG-LD (NBC)...
# 201  KATN (ABC), KFXF-LD (Fox) (KTVF/KXDF-CD), KTVF...
# 202  KAVU-TV (ABC) (KMOL-LD/KUNU-LD (Univision)/KVC...
# 203  WHIZ-TV (NBC); no local ABC, CBS, or Fox affil...
# 204  KHBB-LD (ABC), KHBB-LD2 (Fox/MyNetworkTV/Jewel...
# 205  WAGM-TV (Fox) and WAGM-DT2 (CBS); no local ABC...
# 206  KATH-LD (NBC) (KXLJ-LD), KJUD (ABC), KJUD-DT2 ...
# 207  WBKB-TV (CBS), WBKB-DT2 (Fox/MyNetworkTV), and...
# 208  KHGI-CD (ABC), KIIT-CD (Fox) (KNOP-TV/KNPL-LD)...
# 209  KXGN-TV (CBS) and KXGN-DT2 (NBC); no local ABC...
# 210                                                NaN
# 211                                                NaN
#
# [212 rows x 6 columns]

# %%
dmas.loc[dmas.State=="California", "Market"]
# Out:
# 1                                    Los Angeles
# 5                 San Francisco-Oakland-San Jose
# 19                   Sacramento-Stockton-Modesto
# 27                                     San Diego
# 53                                Fresno-Visalia
# 123    Santa Barbara-Santa Maria-San Luis Obispo
# 124                             Monterey-Salinas
# 125                                  Bakersfield
# 131                                Chico-Redding
# 145                                 Palm Springs
# 194                                       Eureka
# Name: Market, dtype: object

# %% [markdown]
# ## Disqus Comments from The Atlantic

# %%
import requests
disqus_url = "https://disqus.com/embed/comments/?base=default&f=theatlantic&t_i=mt536010&t_u=https%3A%2F%2Fwww.theatlantic.com%2Fscience%2Farchive%2F2017%2F08%2Fadvice-for-eclipse-newbies%2F536010%2F&t_e=Advice%20for%20Eclipse%20Newbies&t_d=Advice%20for%20Eclipse%20Newbies&t_t=Advice%20for%20Eclipse%20Newbies&s_o=default"
article_url = "https://www.theatlantic.com/science/archive/2017/08/advice-for-eclipse-newbies/536010/#article-comments"
r = requests.get(disqus_url, headers={'referer': article_url})

# %%
"Back in the early 90s" in r.text
# Out:
# True

# %%
from urllib.parse import urlencode
import re
from collections import OrderedDict

def get_disqus_url(article_url):
    match = re.search('\/[0-9]{6}\/', article_url)
    if match:
        article_id = match.group()
    else:
        print("Could not extract article_id: {}".format(article_url))
        return(None)
    params = OrderedDict([
        ("base","default"),
        ("f","theatlantic"),
        ("t_i","mt{}".format(article_id)),
        ("t_u",article_url),
        ("s_o","default")
    ])
    query = urlencode(params)
    return("https://disqus.com/embed/comments/?{}".format(query))

# %%
get_disqus_url("https://www.theatlantic.com/politics/archive/2017/%E2%80%A6mmon-error-in-coverage-of-the-google-memo/536181/")
# Out:
# 'https://disqus.com/embed/comments/?base=default&f=theatlantic&t_i=mt%2F536181%2F&t_u=https%3A%2F%2Fwww.theatlantic.com%2Fpolitics%2Farchive%2F2017%2F%25E2%2580%25A6mmon-error-in-coverage-of-the-google-memo%2F536181%2F&s_o=default'

# %% [markdown]
# ## PyQuery Basics

# %%
import requests
from pyquery import PyQuery as PQ

url = "https://arstechnica.com/tech-policy/2017/07/linkedin-its-illegal-to-scrape-our-website-without-permission/"


# Initialize the PyQuery object 
r = requests.get(url)
raw_html = r.text
pq = PQ(raw_html)

# This method downloads the HTML directly from the URL:
pq = PQ(url=url)

# %%
# Links all the a tags (i.e., link tags):
pq("a")
# Out:
# [<a#header-logo>, <a.dropdown-toggle>, <a.nav-search-close>, <a>, <a>, <a>, <a.active>, <a>, <a>, <a>, <a.dropdown-toggle>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a.active>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a.dropdown-toggle>, <a>, <a.signup-btn.button.button-wide>, <a.dropdown-toggle>, <a>, <a>, <a.caption-link>, <a.comment-count.icon-comment-bubble-down>, <a.social-icon.share-facebook>, <a.social-icon.share-twitter>, <a.social-icon.share-reddit>, <a.social-icon.share-gplus>, <a>, <a>, <a>, <a>, <a>, <a>, <a.author-photo>, <a.author-name>, <a>, <a>, <a.comment-count.icon-comment-bubble-down>, <a.social-icon.share-facebook>, <a.social-icon.share-twitter>, <a.social-icon.share-reddit>, <a.social-icon.share-gplus>, <a>, <a.vote_login>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a>, <a.icon.icon-logo-cn-us>, <a>, <a>, <a>, <a>, <a>]

# %%
# Get all the href values from the link tags:
hrefs = []
for a in pq("a"):
    href = pq(a).attr("href")
    hrefs.append(href)
hrefs[0:10]
# Out:
# ['https://arstechnica.com',
#  '/search/',
#  None,
#  '/information-technology/',
#  '/gadgets/',
#  '/science/',
#  '/tech-policy/',
#  '/cars/',
#  '/gaming/',
#  '/civis/']

# %%
# Get full links
hrefs = []
base_url = "https://arstechnica.com"
for a in pq("a")[0:10]:
    href = pq(a).attr("href")
    if not href:
        continue
    if href.startswith("/"):
        href = base_url + href
        hrefs.append(href)
    elif href.startswith("http"):
        hrefs.append(href)
    else:
        continue
hrefs[0:10]
# Out:
# ['https://arstechnica.com',
#  'https://arstechnica.com/search/',
#  'https://arstechnica.com/information-technology/',
#  'https://arstechnica.com/gadgets/',
#  'https://arstechnica.com/science/',
#  'https://arstechnica.com/tech-policy/',
#  'https://arstechnica.com/cars/',
#  'https://arstechnica.com/gaming/',
#  'https://arstechnica.com/civis/']

# %%
# Get full links and link text
links = []
base_url = "https://arstechnica.com"
for a in pq("a"):
    href = pq(a).attr("href")
    if not href:
        continue
    if href.startswith("/"):
        href = base_url + href
    elif not href.startswith("http"):
        continue
    links.append((a.text, href))

links[0:10]
# Out:
# [('\n      ', 'https://arstechnica.com'),
#  ('\n          ', 'https://arstechnica.com/search/'),
#  ('Biz & IT', 'https://arstechnica.com/information-technology/'),
#  ('Tech', 'https://arstechnica.com/gadgets/'),
#  ('Science', 'https://arstechnica.com/science/'),
#  ('Policy', 'https://arstechnica.com/tech-policy/'),
#  ('Cars', 'https://arstechnica.com/cars/'),
#  ('Gaming & Culture', 'https://arstechnica.com/gaming/'),
#  ('Forums', 'https://arstechnica.com/civis/'),
#  ('Videos', 'http://video.arstechnica.com/')]

# %% [markdown]
# ### Quirky things about PyQuery
#
# When you your selector matches more than one element, you will be returned a list of elements. To get a specific element out of this list, you just need to iterate (i.e., using a for loop).
#
# When you have selected a **specific** element (i.e., not a list of elements), you can call `.text` to get out the text associated with that specific tag. This will only give you the *top level* text associated with that tag.
#
# **However!** If you want text that may be embedded within that tag (i.e., inside another child tag), you will want to call the full PyQuery `.text()` extraction function.
#
# To do this, pass your extracted element back into the PyQuery function, and use `.text()`. Example below:

# %%
first_para = pq("div.article-content.post-page > p")[0]
first_para
# Out:
# <Element p at 0x7f50c8611688>

# %%
print(first_para.text)

print("\n")

print(PQ(first_para).text())
# Out:
# A small company called hiQ is locked in a high-stakes battle over
#
#
# A small company called hiQ is locked in a high-stakes battle over Web scraping with LinkedIn. It's a fight that could determine whether an anti-hacking law can be used to curtail the use of scraping tools across the Web.
